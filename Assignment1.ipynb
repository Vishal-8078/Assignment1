# %% [markdown]
# Question 1

# %%
name=input("enter the name") 
roll=int(input("enter the roll number"))
mark=int(input("enter the mark"))
print("Name:",name)
print("Roll No:",roll)
print("Mark:",mark)
# Out:
# enter the nameAnisha
# enter the roll number21
# enter the mark78
# Name: Anisha
# Roll No: 21
# Mark: 78

# %% [markdown]
# Question 2

# %%
fahrenheit=float(input("temperature in fahrenheit:"))
celsius=(fahrenheit-32)*5/9 
print("temperature in celsius:",celsius)
# Out:
# temperature in fahrenheit:41
# temperature in celsius: 5.0

# %% [markdown]
# Question 3

# %%
num1=int(input("enter the first number "))
num2=int(input("enter the second number "))
mul=num1*num2
print("the product of two number is ",mul)
# Out:
# enter the first number 3
# enter the second number 2
# the product of two number is  6

# %% [markdown]
# Question 4

# %%
input_string = "Learn Python by Developing a Website"
formatted_string = input_string.replace("Python", "**Python**").replace("Website", "**Website**") #replace() searches for the specified substring and replaces it
print(formatted_string)
# Out:
# Learn **Python** by Developing a **Website**

# %% [markdown]
# Question 5

# %%
radius = float(input("Enter the radius of the circle: "))
area = 3.14159 * radius**2
print("The area of the circle is:", area)
# Out:
# Enter the radius of the circle: 6
# The area of the circle is: 113.09724

# %% [markdown]
# Question 6

# %%
numbers = [10, 20, 30, 40, 50]
number = int(input("Enter the number to insert: "))
position = int(input("Enter the position to insert: "))
numbers.insert(position, number)
print("Updated list:", numbers)
# Out:
# Enter the number to insert: 60
# Enter the position to insert: 5
# Updated list: [10, 20, 30, 40, 50, 60]

# %% [markdown]
# Question 7

# %%
sample_dict = {"name": "John", "age": 5, "salary": 8000, "city": "New York"}
sample_dict["location"] = sample_dict.pop("city")
print("Updated dictionary:", sample_dict)
# Out:
# Updated dictionary: {'name': 'John', 'age': 5, 'salary': 8000, 'location': 'New York'}

# %% [markdown]
# Question 8

# %%
sample_dict = {
    'emp1': {'name': 'John', 'salary': 7500},
    'emp2': {'name': 'Emma', 'salary': 8000},
    'emp3': {'name': 'Brad', 'salary': 500}
}

sample_dict['emp3']['salary'] = 8500  #salary 8000 is changed to 8500
print("Updated dictionary:")
print(sample_dict)
# Out:
# Updated dictionary:
# {'emp1': {'name': 'John', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# Question 9

# %%
tuple1=(10,20,43,54,56,68)
tuple2=tuple1[2:-2]
tuple2
# Out:
# (43, 54)

# %% [markdown]
# Question 10

# %%
tuple1=(50,10,60,70,50,83,567,50,81)
tuple1.count(50)
# Out:
# 3
